# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
train = pd.read_csv('Data_Train.csv')
test = pd.read_csv('Test_set.csv')

# %%
train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India      01/05/2019   Kolkata    Banglore
# 2      Jet Airways      09/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      09/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India      09/05/2019     Delhi      Cochin
#
#                        Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  22/03/2023 01:10   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR     5:50             13:15   7h 25m     2 stops
# ...

# %%
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL ? BOM ? COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU ? MAA ? BLR    06:20         10:20       4h      1 stop
# ...

# %%
sample=pd.read_csv('Sample_submission.csv')
sample
# Out:
#       Price
# 0     15998
# 1     16612
# 2     25572
# 3     25778
# 4     16934
# ...     ...
# 2666  14046
# 2667  14086
# 2668  22720
# 2669  23544
# 2670  27489
#
# [2671 rows x 1 columns]

# %%
train.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train.shape
# Out:
# (10683, 11)

# %%
test.shape
# Out:
# (2671, 10)

# %%
train['Price'].mean()
# Out:
# 9087.064120565385

# %%
sample['Price']=train['Price'].mean()

# %%
sample
# Out:
#             Price
# 0     9087.064121
# 1     9087.064121
# 2     9087.064121
# 3     9087.064121
# 4     9087.064121
# ...           ...
# 2666  9087.064121
# 2667  9087.064121
# 2668  9087.064121
# 2669  9087.064121
# 2670  9087.064121
#
# [2671 rows x 1 columns]

# %%
sample.to_excel('Price.xlsx', index=False)

# %%
sample
# Out:
#             Price
# 0     9087.064121
# 1     9087.064121
# 2     9087.064121
# 3     9087.064121
# 4     9087.064121
# ...           ...
# 2666  9087.064121
# 2667  9087.064121
# 2668  9087.064121
# 2669  9087.064121
# 2670  9087.064121
#
# [2671 rows x 1 columns]

# %% [markdown]
# first error result was : 0.76684

# %%
result = test[['Source', 'Destination']]
result
# Out:
#         Source Destination
# 0        Delhi      Cochin
# 1      Kolkata    Banglore
# 2        Delhi      Cochin
# 3        Delhi      Cochin
# 4     Banglore       Delhi
# ...        ...         ...
# 2666   Kolkata    Banglore
# 2667   Kolkata    Banglore
# 2668     Delhi      Cochin
# 2669     Delhi      Cochin
# 2670     Delhi      Cochin
#
# [2671 rows x 2 columns]

# %%
result['Price'] = train['Price'].mean()
# Out:
# C:\Users\radia\AppData\Local\Temp\ipykernel_8516\2765323392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['Price'] = train['Price'].mean()

# %%
result
# Out:
#         Source Destination        Price
# 0        Delhi      Cochin  9087.064121
# 1      Kolkata    Banglore  9087.064121
# 2        Delhi      Cochin  9087.064121
# 3        Delhi      Cochin  9087.064121
# 4     Banglore       Delhi  9087.064121
# ...        ...         ...          ...
# 2666   Kolkata    Banglore  9087.064121
# 2667   Kolkata    Banglore  9087.064121
# 2668     Delhi      Cochin  9087.064121
# 2669     Delhi      Cochin  9087.064121
# 2670     Delhi      Cochin  9087.064121
#
# [2671 rows x 3 columns]

# %%
result.to_excel('Source.xlsx','Destination.xlsx', index=False)

# %%
result
# Out:
#         Source Destination        Price
# 0        Delhi      Cochin  9087.064121
# 1      Kolkata    Banglore  9087.064121
# 2        Delhi      Cochin  9087.064121
# 3        Delhi      Cochin  9087.064121
# 4     Banglore       Delhi  9087.064121
# ...        ...         ...          ...
# 2666   Kolkata    Banglore  9087.064121
# 2667   Kolkata    Banglore  9087.064121
# 2668     Delhi      Cochin  9087.064121
# 2669     Delhi      Cochin  9087.064121
# 2670     Delhi      Cochin  9087.064121
#
# [2671 rows x 3 columns]

# %% [markdown]
# second time error result was : 0.76684

# %% [markdown]
# Combine the train + test
#
# Perform the preprocessing
#
# separate the preprocessed train. data
#
# Model on the preprocessed train data
#
# predict on the preprocessed test data

# %%
train['source'] = 'train'
test['source'] = 'test'

# %%
data=pd.concat([train,test])
data
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India      01/05/2019   Kolkata    Banglore
# 2           Jet Airways      09/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                 BLR ? DEL    22:20  22/03/2023 01:10   2h 50m    non-stop
# ...

# %%
data = train.append(test,ignore_index=True)
data
# Out:
# C:\Users\radia\AppData\Local\Temp\ipykernel_8516\1649358099.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = train.append(test,ignore_index=True)
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India      01/05/2019   Kolkata    Banglore
# 2            Jet Airways      09/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# ...

# %%
data.shape
# Out:
# (13354, 12)

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India      01/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      09/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time      Arrival_Time Duration Total_Stops Additional_Info    Price  \
# 0    22:20  22/03/2023 01:10   2h 50m    non-stop         No info   3897.0
# 1     5:50             13:15   7h 25m     2 stops         No info   7662.0
# 2     9:25  10/06/2023 04:25      19h     2 stops         No info  13882.0
# 3    18:05             23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50             21:35   4h 45m      1 stop         No info  13302.0
#
#   source
# 0  train
# 1  train
# 2  train
# 3  train
# ...

# %% [markdown]
# missing value treatment

# %%
data['source'].unique()
# Out:
# array(['train', 'test'], dtype=object)

# %%
data.isna().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# source                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 246

# %%
data.drop_duplicates(inplace=True)

# %%
data.dropna(subset = ['Route','Total_Stops'],inplace = True)

# %%
data.groupby(['Source','Destination'])['Total_Stops'].agg(pd.Series.mode)
# Out:
# Source    Destination
# Banglore  Delhi          non-stop
#           New Delhi        1 stop
# Chennai   Kolkata        non-stop
# Delhi     Cochin           1 stop
# Kolkata   Banglore         1 stop
# Mumbai    Hyderabad      non-stop
# Name: Total_Stops, dtype: object

# %%
data['Total_Stops'] = data.groupby(['Source','Destination'])['Total_Stops'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
data['Total_Stops'].isna().sum()
# Out:
# 0

# %%
data['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
data['Destination'].replace({'New Delhi':'Delhi'},inplace = True)
data
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore       Delhi
# 1              Air India      01/05/2019   Kolkata    Banglore
# 2            Jet Airways      09/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore       Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  22/03/2023 01:10   2h 50m    non-stop
# ...

# %%
data.groupby(['Source','Destination'])['Route'].agg(pd.Series.mode)
# Out:
# Source    Destination
# Banglore  Delhi                BLR ? DEL
# Chennai   Kolkata              MAA ? CCU
# Delhi     Cochin         DEL ? BOM ? COK
# Kolkata   Banglore       CCU ? BOM ? BLR
# Mumbai    Hyderabad            BOM ? HYD
# Name: Route, dtype: object

# %%
data['Route'] = data.groupby(['Source','Destination'])['Route'].transform(lambda x:x.fillna(x.mode()[0]))

# %%
data.isna().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2645
# source                0
# dtype: int64

# %%
data.to_excel('source.xlsx', index=False)

# %%
data
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore       Delhi
# 1              Air India      01/05/2019   Kolkata    Banglore
# 2            Jet Airways      09/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore       Delhi
# ...                  ...             ...       ...         ...
# 13349          Air India       6/06/2019   Kolkata    Banglore
# 13350             IndiGo      27/03/2019   Kolkata    Banglore
# 13351        Jet Airways       6/03/2019     Delhi      Cochin
# 13352          Air India       6/03/2019     Delhi      Cochin
# 13353  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                        Route Dep_Time      Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  22/03/2023 01:10   2h 50m    non-stop
# ...
